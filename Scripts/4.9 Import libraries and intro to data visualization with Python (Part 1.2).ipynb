# %% [markdown]
# # 01. Import libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
# path folder
path = r'C:\Users\alexp\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\alexp\\Instacart Basket Analysis'

# %%
# import customers data set
df_custs_2 = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
# import orders_products_merged_columns_ga.pkl
orders_products_merged_columns_ga_2 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_columns_ga.pkl'))

# %% [markdown]
# # 03. Data Wrangling
# ## Q4

# %% [markdown]
# ## Renaming columns

# %%
df_custs_2.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
orders_products_merged_columns_ga_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...    price_range_loc     busiest_day  busiest_days  \
# ...

# %%
# display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
# renaming columns
df_custs_2.rename(columns = {'First Name' : 'first_name', 'Surnam' : 'last_name', 'Gender' : 'gender', 'STATE' : 'state', 'Age' : 'age', 'n_dependants' : 'number_of_dependents', 'fam_status' : 'family_status'}, inplace = True)

# %%
df_custs_2.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %%
df_custs_2.describe()
# Out:
#              user_id            age  number_of_dependents         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
orders_products_merged_columns_ga_2.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ## Q5

# %% [markdown]
# ## Data consistency checks

# %%
df_custs_2.shape
# Out:
# (206209, 10)

# %%
df_custs_2.describe()
# Out:
#              user_id            age  number_of_dependents         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %% [markdown]
# ## Mixed-type data

# %%
# check for mixed-type data in df_custs dataframe
for col in df_custs_2.columns.tolist():
    weird = (df_custs_2[[col]].applymap(type) != df_custs_2[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_custs_2[weird]) > 0:
        print(col)
# Out:
# first_name

# %% [markdown]
# ### First_name column contains mixed-type data.

# %%
df_custs_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               206209 non-null  int64
#  1   first_name            194950 non-null  object
#  2   last_name             206209 non-null  object
#  3   gender                206209 non-null  object
#  4   state                 206209 non-null  object
#  5   age                   206209 non-null  int64
#  6   date_joined           206209 non-null  object
#  7   number_of_dependents  206209 non-null  int64
#  8   family_status         206209 non-null  object
#  9   income                206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
orders_products_merged_columns_ga_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  _merge                  category
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  max_spender             float64
# ...

# %% [markdown]
# ## Missing values

# %%
# run a check for missing values
df_custs_2.isnull().sum()
# Out:
# user_id                     0
# first_name              11259
# last_name                   0
# gender                      0
# state                       0
# age                         0
# date_joined                 0
# number_of_dependents        0
# family_status               0
# income                      0
# dtype: int64

# %% [markdown]
# ### There are 11259 missing values under the first_name column in the df_custs dataframe.

# %%
# view the 11259 missing values
df_custs_2_nan = df_custs_2[df_custs_2['first_name'].isnull() == True]
df_custs_2_nan
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         number_of_dependents family_status  income
# ...

# %% [markdown]
# ### No changes will be made since the missing values (NaNs) under the first_name column can hold an importance just as much as the non-missing values.

# %%
df_custs_2.shape
# Out:
# (206209, 10)

# %% [markdown]
# ## Finding duplicates

# %%
# run a check for duplicate values
df_custs_2_dups = df_custs_2[df_custs_2.duplicated()]
df_custs_2_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, number_of_dependents, family_status, income]
# Index: []

# %% [markdown]
# ### There are no duplicates in the df_custs_2 dataframe.

# %% [markdown]
# ## Q6

# %% [markdown]
# ## Change data types for columns to allow faster merging

# %%
df_custs_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               206209 non-null  int64
#  1   first_name            194950 non-null  object
#  2   last_name             206209 non-null  object
#  3   gender                206209 non-null  object
#  4   state                 206209 non-null  object
#  5   age                   206209 non-null  int64
#  6   date_joined           206209 non-null  object
#  7   number_of_dependents  206209 non-null  int64
#  8   family_status         206209 non-null  object
#  9   income                206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df_custs_2.describe()
# Out:
#              user_id            age  number_of_dependents         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
df_custs_2.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependents family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %%
orders_products_merged_columns_ga_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       int64
#  8   reordered               int64
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  _merge                  category
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  max_spender             float64
# ...

# %%
orders_products_merged_columns_ga_2.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07        3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01        2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01        2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00        1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01        3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
orders_products_merged_columns_ga_2.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ## Changing data types to columns for faster merging

# %%
# changing data types from df_custs_2 dataframe
df_custs_2['user_id'] = df_custs_2['user_id'].astype('str')
df_custs_2['age'] = df_custs_2['age'].astype('int8')
df_custs_2['number_of_dependents'] = df_custs_2['number_of_dependents'].astype('int8')
df_custs_2['income'] = df_custs_2['income'].astype('int32')

# %%
df_custs_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   user_id               206209 non-null  object
#  1   first_name            194950 non-null  object
#  2   last_name             206209 non-null  object
#  3   gender                206209 non-null  object
#  4   state                 206209 non-null  object
#  5   age                   206209 non-null  int8
#  6   date_joined           206209 non-null  object
#  7   number_of_dependents  206209 non-null  int8
#  8   family_status         206209 non-null  object
#  9   income                206209 non-null  int32
# dtypes: int32(1), int8(2), object(7)
# memory usage: 12.2+ MB

# %%
df_custs_2.describe()
# Out:
#                  age  number_of_dependents         income
# count  206209.000000         206209.000000  206209.000000
# mean       49.501646              1.499823   94632.852548
# std        18.480962              1.118433   42473.786988
# min        18.000000              0.000000   25903.000000
# 25%        33.000000              0.000000   59874.000000
# 50%        49.000000              1.000000   93547.000000
# 75%        66.000000              3.000000  124244.000000
# max        81.000000              3.000000  593901.000000

# %%
df_custs_2[['user_id', 'age', 'number_of_dependents', 'income']].head(10)
# Out:
#   user_id  age  number_of_dependents  income
# 0   26711   48                     3  165665
# 1   33890   36                     0   59285
# 2   65803   35                     2   99568
# 3  125935   40                     0   42049
# 4  130797   26                     1   40374
# 5  133128   43                     2   49643
# 6  152052   20                     0   61746
# 7  168851   30                     0   63712
# 8   69965   47                     1  162432
# 9   82820   26                     2   32072

# %%
# changing data types from orders_products_merged_columns_ga_2 dataframe
orders_products_merged_columns_ga_2['order_id'] = orders_products_merged_columns_ga_2['order_id'].astype('str')
orders_products_merged_columns_ga_2['user_id'] = orders_products_merged_columns_ga_2['user_id'].astype('str')
orders_products_merged_columns_ga_2['order_number'] = orders_products_merged_columns_ga_2['order_number'].astype('int8')
orders_products_merged_columns_ga_2['orders_day_of_week'] = orders_products_merged_columns_ga_2['orders_day_of_week'].astype('int8')
orders_products_merged_columns_ga_2['order_hour_of_day'] = orders_products_merged_columns_ga_2['order_hour_of_day'].astype('int8')
orders_products_merged_columns_ga_2['days_since_prior_order'] = orders_products_merged_columns_ga_2['days_since_prior_order'].astype('float16')
orders_products_merged_columns_ga_2['product_id'] = orders_products_merged_columns_ga_2['product_id'].astype('int32')
orders_products_merged_columns_ga_2['add_to_cart_order'] = orders_products_merged_columns_ga_2['add_to_cart_order'].astype('int32')
orders_products_merged_columns_ga_2['reordered'] = orders_products_merged_columns_ga_2['reordered'].astype('int8')
orders_products_merged_columns_ga_2['aisle_id'] = orders_products_merged_columns_ga_2['aisle_id'].astype('int8')
orders_products_merged_columns_ga_2['department_id'] = orders_products_merged_columns_ga_2['department_id'].astype('int32')
orders_products_merged_columns_ga_2['prices'] = orders_products_merged_columns_ga_2['prices'].astype('float32')
orders_products_merged_columns_ga_2['max_order'] = orders_products_merged_columns_ga_2['max_order'].astype('int8')
orders_products_merged_columns_ga_2['max_spender'] = orders_products_merged_columns_ga_2['max_spender'].astype('float16')
orders_products_merged_columns_ga_2['ordering_behavior'] = orders_products_merged_columns_ga_2['ordering_behavior'].astype('float16')

# %%
orders_products_merged_columns_ga_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            int8
#  3   orders_day_of_week      int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float16
#  6   product_id              int32
#  7   add_to_cart_order       int32
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int8
#  11  department_id           int32
#  12  prices                  float32
#  13  _merge                  category
#  14  price_range_loc         object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int8
#  19  loyalty_flag            object
#  20  max_spender             float16
# ...

# %%
orders_products_merged_columns_ga_2.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.240486e+07        3.240486e+07       3.240486e+07
# mean   1.714230e+01        2.738867e+00       1.342515e+01
# std    1.753532e+01        2.090077e+00       4.246380e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.400000e+01        5.000000e+00       1.600000e+01
# max    9.900000e+01        6.000000e+00       2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count              30328763.0  3.240486e+07       3.240486e+07  3.240486e+07
# mean                      NaN  2.559866e+04       8.352547e+00  5.895873e-01
# std                       0.0  1.408400e+04       7.127071e+00  4.919087e-01
# min                       0.0  1.000000e+00       1.000000e+00  0.000000e+00
# ...

# %%
orders_products_merged_columns_ga_2.head(10)
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
# 5  3367565       1             6                   2                  7
# 6   550135       1             7                   1                  9
# 7  3108588       1             8                   1                 14
# 8  2295261       1             9                   1                 16
# 9  2550362       1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %% [markdown]
# ## Combining data

# %%
# check the total size of orders_products_merged_columns_ga_2.pkl
orders_products_merged_columns_ga_2.shape
# Out:
# (32404859, 24)

# %%
# check the total size of customers.csv
df_custs_2.shape
# Out:
# (206209, 10)

# %%
# merge the df_custs_2 dataframe with orders_products_merged_columns_ga_2 dataframe
df_orders_products_customers_merged_2 = orders_products_merged_columns_ga_2.merge(df_custs_2, on = 'user_id', how = 'outer')

# %% [markdown]
# ### Using argument how = 'outer' will combine all the observations and show the real merge rate.

# %%
# Check df_orders_products_customers_merged_2 output
df_orders_products_customers_merged_2.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
# Check the value counts in df_orders_products_customers_merged_2 dataframe
df_orders_products_customers_merged_2['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# check total size of the df_orders_products_customers_merged_2 dataframe
df_orders_products_customers_merged_2.shape
# Out:
# (32404859, 33)

# %%
df_orders_products_customers_merged_2
# Out:
#          order_id user_id  order_number  orders_day_of_week  \
# 0         2539329       1             1                   2
# 1         2398795       1             2                   3
# 2          473747       1             3                   3
# 3         2254736       1             4                   4
# 4          431534       1             5                   4
# ...           ...     ...           ...                 ...
# 32404854   156685  106143            26                   4
# 32404855   484769   66343             1                   6
# 32404856  1561557   66343             2                   1
# 32404857   276317   66343             3                   6
# 32404858  2922475   66343             4                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %% [markdown]
# ## Q8

# %%
# Export df_orders_products_customers_merged_2 to pkl
df_orders_products_customers_merged_2.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers_merged_2.pkl'))
